# %%
colors = ["red", "blue", "green"]   # 리스트 생성
colors.append("yellow") # 리스트에 새로운 요소 추가
# Out:
# 'Python 3.12.3'(으)로 셀을 실행하려면 ipykernel 패키지가 필요합니다.
#
# 다음 명령어를 실행하여 Python 환경에 'ipykernel'을(를) 설치합니다.
#
#  명령: '/usr/bin/python3 -m pip install ipykernel -U --user --force-reinstall'
