# %%
print("Hello World!")
# Out:
# Hello World!

# %%
1+2
# Out:
# 3

# %%
# 12345
# 54321

#	문자열로 변환한 후 뒤집을 수 있습니다.
#	또는, 수학적 계산을 이용해 뒤집을 수도 있습니다.


num = ("12345")[::-1]
print(num)
# Out:
# 54321

# %%
number = int(input("숫자를 입력하세요: "))
if number % 2 == 0:
    print("짝수입니다.")
else:
    print("홀수입니다.")
# Out:
# 짝수입니다.

# %%
# 첫 번째 숫자를 입력하세요: 5
# 두 번째 숫자를 입력하세요: 3

number1 = int(input("첫 번째 숫자를 입력하세요: "))
number2 = int(input("두 번째 숫자를 입력하세요: "))
num = number1 + number2
print(f"두 숫자의 합은: {num}입니다.")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[10], line 7
#       5 number2 = int(input("두 번째 숫자를 입력하세요: "))
#       6 num = number1 + number2
# ----> 7 print(f"두 숫자의 합은: {num}입니다.")
#
# TypeError: 'int' object is not callable

# %%
num = int(input("숫자를 입력하세요: "))
result = sum(range(1, num + 1))
print(f"1부터 {num}까지의 합은 {result}입니다.")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 num = int(input("숫자를 입력하세요: "))
#       2 result = sum(range(1, num + 1))
#       3 print(f"1부터 {num}까지의 합은 {result}입니다.")
#
# ValueError: invalid literal for int() with base 10: '\x086'
