# %%
try:
    1 / 0
except ZeroDivisionError:
    print("예외 정보 : ", sys.exc_info())

# %%
try:
    result = 10 / 0     # ZeroDivisionError
except ZeroDivisionError:
    print("0으로 나눌 수 없습니다.")
else:
    print("예외가 발생하지 않았습니다.")
finally:
    print("예외 처리 완료")
# Out:
# 0으로 나눌 수 없습니다.
# 예외 처리 완료

# %%
try:
    raise ValueError("잘못된 값")
except ValueError as e:
    raise TypeError("타입 오류")

# %%
import os
# 경로 합치기 예제 documents와 example
file_path = os.path.join("documents", "example.txt")
print("파일 경로 : ", file_path)
print("절대 경로 : ", os.abspath(file_path))
print("파일 존재 여부 : ", os.path.exists(file_path))
print("파일명과 확장자 : ", os.path.splitext(file_path))
