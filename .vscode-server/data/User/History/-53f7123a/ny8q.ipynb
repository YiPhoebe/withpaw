# %%
from database import initialize_database, reset_database
from user_management import set_user_profile, login
from pet_management import add_pet, update_pet

if __name__ == "__main__":
    initialize_database()
    while True:
        print("\n1. Create User Profile")
        print("2. Login")
        print("3. Add Pet")
        print("4. Update Pet")
        print("5. Exit")
        choice = input("Select: ")
        if choice == "1":
            set_user_profile()
        elif choice == "2":
            login()
        elif choice == "3":
            add_pet()
        elif choice == "4":
            update_pet()
        elif choice == "5":
            print("Exiting WithPaw. Goodbye!")
            break
        else:
            print("Invalid choice, try again.")

# main.ipynb 안에서
# %run database.ipynb
# %run user_management.ipynb

initialize_database()  # database.ipynb에서 가져온 함수
set_user_profile()  # user_management.ipynb에서 가져온 함수
